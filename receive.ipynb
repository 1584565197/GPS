# %%
import re
from datetime import datetime
import math
import webbrowser
from urllib.parse import urlencode
import os
import serial
import time

def parse_serial_data(serial_port, baud_rate=115200, timeout=1, receive_time=5):
    """从串口读取经纬度数据，固定接收指定时间"""
    try:
        ser = serial.Serial(serial_port, baud_rate, timeout=timeout)
        print(f"成功打开串口: {serial_port}, 波特率: {baud_rate}")
        print(f"开始接收数据，将持续 {receive_time} 秒...")
        
        coordinates = []
        start_time = time.time()
        raw_data_buffer = ""
        
        try:
            buffer = ""
            
            while time.time() - start_time < receive_time:
                data = ser.read(ser.in_waiting or 1).decode('utf-8', errors='ignore')
                if not data:
                    continue
                    
                raw_data_buffer += data
                buffer += data
                
                # 打印原始数据片段
                if data:
                    print(f"[原始数据] {data.strip() or '<空>'}")
                
                # 匹配格式: 纬度,经度 或 纬度,经度
                matches = re.findall(r'?([\d.]+),([\d.]+)', buffer)
                
                for lat_str, lng_str in matches:
                    try:
                        lat = float(lat_str)
                        lng = float(lng_str)
                        
                        # 恢复经纬度校验
                        if -90 <= lat <= 90 and -180 <= lng <= 180:
                            coordinates.append((lng, lat))
                            print(f"[解析成功] WGS84坐标: 经度={lng:.6f}, 纬度={lat:.6f}")
                        else:
                            print(f"[范围错误] 经纬度超出范围: 经度={lng}, 纬度={lat}")
                    except Exception as e:
                        print(f"[解析失败] 错误: {e}, 原始数据: {lat_str},{lng_str}")
                
                # 从缓冲区移除已处理的数据
                if matches:
                    last_match_end = buffer.rfind(matches[-1][1]) + len(matches[-1][1])
                    buffer = buffer[last_match_end:]
                
                time.sleep(0.01)  # 减轻CPU负担
                
            print(f"\n数据接收完成，共耗时 {time.time() - start_time:.2f} 秒")
            print(f"[调试] 原始数据总长度: {len(raw_data_buffer)} 字符")
            print(f"[调试] 原始数据预览: {raw_data_buffer[:100]}...")
            
        except KeyboardInterrupt:
            print("\n用户中断，停止接收数据")
        finally:
            ser.close()
        
        return coordinates
    
    except serial.SerialException as e:
        print(f"串口打开失败: {e}")
        return []
    except Exception as e:
        print(f"接收数据时出错: {e}")
        return []

def print_received_data(coordinates):
    """打印所有接收到的WGS84坐标数据"""
    if not coordinates:
        print("没有接收到有效坐标数据")
        return
    
    print("\n===== 接收到的WGS84坐标数据 =====")
    for i, (lng, lat) in enumerate(coordinates):
        print(f"{i+1}. WGS84坐标: 经度={lng:.6f}, 纬度={lat:.6f}")
    print(f"===== 共 {len(coordinates)} 个坐标点 =====")

def display_coordinates(coordinates):
    """显示接收到的WGS84坐标数据摘要"""
    if not coordinates:
        print("没有接收到有效坐标数据")
        return []
    
    print("\n===== 接收到的WGS84坐标数据摘要 =====")
    
    for i, (lng, lat) in enumerate(coordinates):
        print(f"--- 坐标 {i+1} ---")
        print(f"  WGS84坐标: 经度={lng:.6f}, 纬度={lat:.6f}")
    
    print(f"\n===== 接收完成，共{len(coordinates)}个坐标点 =====")
    return coordinates

def convert_to_gcj02(coordinates):
    """将WGS84坐标转换为GCJ02坐标"""
    gcj_coordinates = []
    for lng, lat in coordinates:
        gcj_lng, gcj_lat = wgs84togcj02(lng, lat)
        gcj_coordinates.append((gcj_lng, gcj_lat))
        print(f"[转换完成] GCJ02坐标: 经度={gcj_lng:.6f}, 纬度={gcj_lat:.6f}")
    return gcj_coordinates

def create_amap_html(coordinates, title="实时轨迹地图", output_file="route——map.html"):
    """创建高德地图HTML文件，显示轨迹（使用GCJ02坐标）"""
    if not coordinates:
        print("没有有效的坐标数据，无法生成地图")
        return None
    
    points_str = ",\n        ".join([f"[{lng}, {lat}]" for lng, lat in coordinates])
    default_center = [116.403988, 39.91512]
    center_lng = sum(lng for lng, lat in coordinates) / len(coordinates) if coordinates else default_center[0]
    center_lat = sum(lat for lng, lat in coordinates) / len(coordinates) if coordinates else default_center[1]
    
    html_content = f"""<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <script src="https://webapi.amap.com/maps?v=2.0&key={AMAP_API_KEY}"></script>
    <style>
        html, body, #container {{ width: 100%; height: 800px; margin: 0; padding: 0; }}
    </style>
</head>
<body>
    <div id="container"></div>
    <script type="text/javascript">
        var map = new AMap.Map('container', {{
            zoom: 13,
            center: [{center_lng}, {center_lat}]
        }});
        
        var path = [{points_str}];
        var polyline = new AMap.Polyline({{
            path: path,
            strokeColor: "#FF33FF",
            strokeWeight: 5,
            strokeOpacity: 0.8,
            lineJoin: 'round',
            lineCap: 'round',
            zIndex: 50,
            geodesic: true
        }});
        polyline.setMap(map);
        
        var startPoint = path[0];
        var endPoint = path[path.length - 1];
        
        new AMap.Marker({{
            position: startPoint,
            icon: "https://webapi.amap.com/theme/v1.3/markers/n/mark_b.png",
            offset: new AMap.Pixel(-10, -34)
        }}).setMap(map);
        
        new AMap.Marker({{
            position: endPoint,
            icon: "https://webapi.amap.com/theme/v1.3/markers/n/mark_r.png",
            offset: new AMap.Pixel(-10, -34)
        }}).setMap(map);
        
        map.setFitView();
    </script>
</body>
</html>"""
    
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(html_content)
    
    return output_file

def show_realtime_track(coordinates, title="实时轨迹地图", output_file="realtime_map.html"):
    """显示实时轨迹地图（使用GCJ02坐标）"""
    if not coordinates:
        print("没有有效的坐标数据，无法生成地图")
        return
    
    # 转换坐标
    gcj_coordinates = convert_to_gcj02(coordinates)
    
    # 生成地图
    map_file = create_amap_html(gcj_coordinates, title, output_file)
    if map_file:
        # 使用绝对路径打开
        file_url = f"file:///{os.path.abspath(map_file)}"
        webbrowser.open_new_tab(file_url)
        print(f"已生成实时轨迹地图: {map_file}")
        print(f"轨迹包含 {len(gcj_coordinates)} 个GCJ02坐标点")
        print(f"起点GCJ02坐标: 经度 {gcj_coordinates[0][0]:.6f}, 纬度 {gcj_coordinates[0][1]:.6f}")
        print(f"终点GCJ02坐标: 经度 {gcj_coordinates[-1][0]:.6f}, 纬度 {gcj_coordinates[-1][1]:.6f}")

def main():
    # 配置串口（根据实际情况修改）
    serial_port = "COM6"  # Windows串口示例，Linux/Mac可能为 "/dev/ttyUSB0"
    baud_rate = 115200
    receive_duration = 5  # 数据接收持续时间（秒）
    
    print("=== 高德地图实时轨迹绘制程序 ===")
    print("请确保串口已连接并发送WGS84格式经纬度数据")
    
    # 从串口接收数据
    gps_coordinates = parse_serial_data(serial_port, baud_rate, receive_time=receive_duration)
    
    if gps_coordinates:
        # 打印WGS84坐标数据
        print_received_data(gps_coordinates)
        
        # 显示WGS84坐标摘要
        coordinates = display_coordinates(gps_coordinates)
        
        # 生成并显示地图（自动转换为GCJ02坐标）
        show_realtime_track(coordinates, "WGS84转GCJ02轨迹地图")
    else:
        print("\n[错误] 未接收到有效坐标数据，请检查：")
        print("1. 串口是否正确连接（端口号：COM9）")
        print("2. 波特率是否匹配（115200）")
        print("3. 数据格式是否为：纬度,经度 或 纬度,经度")

if __name__ == "__main__":
    main()
# Out:
# === 高德地图实时轨迹绘制程序 ===
# 请确保串口已连接并发送WGS84格式经纬度数据
# 成功打开串口: COM6, 波特率: 115200
# 开始接收数据，将持续 5 秒...
# [原始数据] 2
# [原始数据] 9.715706,106.784225
# 29.715702,106.784225
# 29.715702,106.784248
# 29.715702,106.784248
# 29.715702,106.784264
# 29.715702,106.784264
# 29.715702,106.784279
# 29.715702,106.784294
# 29.715706,106.784309
# 29.715706,106.784325
# 29.715702,106.784340
# 29.715698,106.784355
# 29.715702,106.784378
# 29.715702,106.784393
#
# [解析成功] WGS84坐标: 经度=106.784225, 纬度=29.715706
# [解析成功] WGS84坐标: 经度=106.784225, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784248, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784248, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784264, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784264, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784279, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784294, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784309, 纬度=29.715706
# [解析成功] WGS84坐标: 经度=106.784325, 纬度=29.715706
# [解析成功] WGS84坐标: 经度=106.784340, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784355, 纬度=29.715698
# [解析成功] WGS84坐标: 经度=106.784378, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784393, 纬度=29.715702
# [原始数据] 29.715702,106.784409
# 29.715702,106.784424
# 29.715702,106.784439
# 29.715698,106.784454
# 29.715702,106.784454
# 29.715702,106.784470
# 29.715698,106.784492
# 29.715702,106.784508
# 29.715706,106.784523
# 29.715710,106.784538
# 29.715702,106.784554
# 29.715694,106.784569
# 29.715681,106.784569
# 29.715681,106.784584
#
# [解析成功] WGS84坐标: 经度=106.784409, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784424, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784439, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784454, 纬度=29.715698
# [解析成功] WGS84坐标: 经度=106.784454, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784470, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784492, 纬度=29.715698
# [解析成功] WGS84坐标: 经度=106.784508, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784523, 纬度=29.715706
# [解析成功] WGS84坐标: 经度=106.784538, 纬度=29.715710
# [解析成功] WGS84坐标: 经度=106.784554, 纬度=29.715702
# [解析成功] WGS84坐标: 经度=106.784569, 纬度=29.715694
# [解析成功] WGS84坐标: 经度=106.784569, 纬度=29.715681
# [解析成功] WGS84坐标: 经度=106.784584, 纬度=29.715681
# [原始数据] 29.715677,106.784599
# 29.715670,106.784622
# 29.715662,106.784637
# 29.715658,106.784653
# 29.715654,106.784668
# 29.715645,106.784683
# 29.715588,106.784683
# 29.715576,106.784683
# 29.715584,106.784683
# 29.715580,106.784698
# 29.715576,106.784698
# 29.715576,106.784698
# 29.715576,106.784714
#
# [解析成功] WGS84坐标: 经度=106.784599, 纬度=29.715677
# [解析成功] WGS84坐标: 经度=106.784622, 纬度=29.715670
# [解析成功] WGS84坐标: 经度=106.784637, 纬度=29.715662
# [解析成功] WGS84坐标: 经度=106.784653, 纬度=29.715658
# [解析成功] WGS84坐标: 经度=106.784668, 纬度=29.715654
# [解析成功] WGS84坐标: 经度=106.784683, 纬度=29.715645
# [解析成功] WGS84坐标: 经度=106.784683, 纬度=29.715588
# [解析成功] WGS84坐标: 经度=106.784683, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784683, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.784698, 纬度=29.715580
# [解析成功] WGS84坐标: 经度=106.784698, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784698, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784714, 纬度=29.715576
# [原始数据] 29.715576,106.784737
# 29.715576,106.784737
# 29.715576,106.784752
# 29.715576,106.784767
# 29.715576,106.784767
# 29.715576,106.784782
# 29.715572,106.784782
# 29.715576,106.784798
# 29.715576,106.784798
# 29.715584,106.784813
# 29.715601,106.784828
# 29.715609,106.784843
# 29.715616,106.784866
#
# [解析成功] WGS84坐标: 经度=106.784737, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784737, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784752, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784767, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784767, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784782, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784782, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.784798, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784798, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.784813, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.784828, 纬度=29.715601
# [解析成功] WGS84坐标: 经度=106.784843, 纬度=29.715609
# [解析成功] WGS84坐标: 经度=106.784866, 纬度=29.715616
# [原始数据] 29.715626,106.784882
# 29.715633,106.784897
# 29.715641,106.784912
# 29.715654,106.784927
# 29.715670,106.784943
# 29.715677,106.784958
# 29.715677,106.784981
# 29.715687,106.784996
# 29.715687,106.784996
# 29.715687,106.785011
# 29.715687,106.785011
# 29.715681,106.785027
# 29.715677,106.785027
#
# [解析成功] WGS84坐标: 经度=106.784882, 纬度=29.715626
# [解析成功] WGS84坐标: 经度=106.784897, 纬度=29.715633
# [解析成功] WGS84坐标: 经度=106.784912, 纬度=29.715641
# [解析成功] WGS84坐标: 经度=106.784927, 纬度=29.715654
# [解析成功] WGS84坐标: 经度=106.784943, 纬度=29.715670
# [解析成功] WGS84坐标: 经度=106.784958, 纬度=29.715677
# [解析成功] WGS84坐标: 经度=106.784981, 纬度=29.715677
# [解析成功] WGS84坐标: 经度=106.784996, 纬度=29.715687
# [解析成功] WGS84坐标: 经度=106.784996, 纬度=29.715687
# [解析成功] WGS84坐标: 经度=106.785011, 纬度=29.715687
# [解析成功] WGS84坐标: 经度=106.785011, 纬度=29.715687
# [解析成功] WGS84坐标: 经度=106.785027, 纬度=29.715681
# [解析成功] WGS84坐标: 经度=106.785027, 纬度=29.715677
# [原始数据] 29.715670,106.785042
# 29.715666,106.785042
# 29.715662,106.785057
# 29.715662,106.785057
# 29.715654,106.785072
# 29.715645,106.785088
# 29.715633,106.785126
# 29.715620,106.785126
# 29.715609,106.785141
# 29.715601,106.785156
# 29.715593,106.785156
# 29.715588,106.785172
# 29.715580,106.785187
#
# [解析成功] WGS84坐标: 经度=106.785042, 纬度=29.715670
# [解析成功] WGS84坐标: 经度=106.785042, 纬度=29.715666
# [解析成功] WGS84坐标: 经度=106.785057, 纬度=29.715662
# [解析成功] WGS84坐标: 经度=106.785057, 纬度=29.715662
# [解析成功] WGS84坐标: 经度=106.785072, 纬度=29.715654
# [解析成功] WGS84坐标: 经度=106.785088, 纬度=29.715645
# [解析成功] WGS84坐标: 经度=106.785126, 纬度=29.715633
# [解析成功] WGS84坐标: 经度=106.785126, 纬度=29.715620
# [解析成功] WGS84坐标: 经度=106.785141, 纬度=29.715609
# [解析成功] WGS84坐标: 经度=106.785156, 纬度=29.715601
# [解析成功] WGS84坐标: 经度=106.785156, 纬度=29.715593
# [解析成功] WGS84坐标: 经度=106.785172, 纬度=29.715588
# [解析成功] WGS84坐标: 经度=106.785187, 纬度=29.715580
# [原始数据] 29.715576,106.785202
# 29.715572,106.785202
# 29.715572,106.785225
# 29.715572,106.785240
# 29.715572,106.785255
# 29.715572,106.785255
# 29.715576,106.785271
# 29.715580,106.785286
# 29.715584,106.785286
# 29.715584,106.785301
# 29.715588,106.785316
# 29.715593,106.785316
# 29.715597,106.785332
#
# [解析成功] WGS84坐标: 经度=106.785202, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.785202, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.785225, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.785240, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.785255, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.785255, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.785271, 纬度=29.715576
# [解析成功] WGS84坐标: 经度=106.785286, 纬度=29.715580
# [解析成功] WGS84坐标: 经度=106.785286, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.785301, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.785316, 纬度=29.715588
# [解析成功] WGS84坐标: 经度=106.785316, 纬度=29.715593
# [解析成功] WGS84坐标: 经度=106.785332, 纬度=29.715597
# [原始数据] 29.715597,106.785355
# 29.715597,106.785370
# 29.715593,106.785370
# 29.715593,106.785385
# 29.715593,106.785400
# 29.715593,106.785416
# 29.715588,106.785416
# 29.715584,106.785416
# 29.715584,106.785431
# 29.715584,106.785431
# 29.715580,106.785431
# 29.715572,106.785446
# 29.715569,106.785469
# 29.715559,106.785484
# 29.715555,106.785484
#
# [解析成功] WGS84坐标: 经度=106.785355, 纬度=29.715597
# [解析成功] WGS84坐标: 经度=106.785370, 纬度=29.715597
# [解析成功] WGS84坐标: 经度=106.785370, 纬度=29.715593
# [解析成功] WGS84坐标: 经度=106.785385, 纬度=29.715593
# [解析成功] WGS84坐标: 经度=106.785400, 纬度=29.715593
# [解析成功] WGS84坐标: 经度=106.785416, 纬度=29.715593
# [解析成功] WGS84坐标: 经度=106.785416, 纬度=29.715588
# [解析成功] WGS84坐标: 经度=106.785416, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.785431, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.785431, 纬度=29.715584
# [解析成功] WGS84坐标: 经度=106.785431, 纬度=29.715580
# [解析成功] WGS84坐标: 经度=106.785446, 纬度=29.715572
# [解析成功] WGS84坐标: 经度=106.785469, 纬度=29.715569
# [解析成功] WGS84坐标: 经度=106.785484, 纬度=29.715559
# [解析成功] WGS84坐标: 经度=106.785484, 纬度=29.715555
# [原始数据] 29.715555,106.785500
# 29.715551,106.785515
#
# [解析成功] WGS84坐标: 经度=106.785500, 纬度=29.715555
# [解析成功] WGS84坐标: 经度=106.785515, 纬度=29.715551
#
# 数据接收完成，共耗时 5.62 秒
# [调试] 原始数据总长度: 3300 字符
# [调试] 原始数据预览: 29.715706,106.784225
# 29.715702,106.784225
# 29.715702,106.784248
# 29.715702,...
#
# ===== 接收到的WGS84坐标数据 =====
# 1. WGS84坐标: 经度=106.784225, 纬度=29.715706
# 2. WGS84坐标: 经度=106.784225, 纬度=29.715702
# 3. WGS84坐标: 经度=106.784248, 纬度=29.715702
# 4. WGS84坐标: 经度=106.784248, 纬度=29.715702
# 5. WGS84坐标: 经度=106.784264, 纬度=29.715702
# 6. WGS84坐标: 经度=106.784264, 纬度=29.715702
# 7. WGS84坐标: 经度=106.784279, 纬度=29.715702
# 8. WGS84坐标: 经度=106.784294, 纬度=29.715702
# 9. WGS84坐标: 经度=106.784309, 纬度=29.715706
# 10. WGS84坐标: 经度=106.784325, 纬度=29.715706
# 11. WGS84坐标: 经度=106.784340, 纬度=29.715702
# 12. WGS84坐标: 经度=106.784355, 纬度=29.715698
# 13. WGS84坐标: 经度=106.784378, 纬度=29.715702
# 14. WGS84坐标: 经度=106.784393, 纬度=29.715702
# 15. WGS84坐标: 经度=106.784409, 纬度=29.715702
# 16. WGS84坐标: 经度=106.784424, 纬度=29.715702
# 17. WGS84坐标: 经度=106.784439, 纬度=29.715702
# 18. WGS84坐标: 经度=106.784454, 纬度=29.715698
# 19. WGS84坐标: 经度=106.784454, 纬度=29.715702
# 20. WGS84坐标: 经度=106.784470, 纬度=29.715702
# 21. WGS84坐标: 经度=106.784492, 纬度=29.715698
# 22. WGS84坐标: 经度=106.784508, 纬度=29.715702
# 23. WGS84坐标: 经度=106.784523, 纬度=29.715706
# 24. WGS84坐标: 经度=106.784538, 纬度=29.715710
# 25. WGS84坐标: 经度=106.784554, 纬度=29.715702
# 26. WGS84坐标: 经度=106.784569, 纬度=29.715694
# 27. WGS84坐标: 经度=106.784569, 纬度=29.715681
# 28. WGS84坐标: 经度=106.784584, 纬度=29.715681
# 29. WGS84坐标: 经度=106.784599, 纬度=29.715677
# 30. WGS84坐标: 经度=106.784622, 纬度=29.715670
# 31. WGS84坐标: 经度=106.784637, 纬度=29.715662
# 32. WGS84坐标: 经度=106.784653, 纬度=29.715658
# 33. WGS84坐标: 经度=106.784668, 纬度=29.715654
# 34. WGS84坐标: 经度=106.784683, 纬度=29.715645
# 35. WGS84坐标: 经度=106.784683, 纬度=29.715588
# 36. WGS84坐标: 经度=106.784683, 纬度=29.715576
# 37. WGS84坐标: 经度=106.784683, 纬度=29.715584
# 38. WGS84坐标: 经度=106.784698, 纬度=29.715580
# 39. WGS84坐标: 经度=106.784698, 纬度=29.715576
# 40. WGS84坐标: 经度=106.784698, 纬度=29.715576
# 41. WGS84坐标: 经度=106.784714, 纬度=29.715576
# 42. WGS84坐标: 经度=106.784737, 纬度=29.715576
# 43. WGS84坐标: 经度=106.784737, 纬度=29.715576
# 44. WGS84坐标: 经度=106.784752, 纬度=29.715576
# 45. WGS84坐标: 经度=106.784767, 纬度=29.715576
# 46. WGS84坐标: 经度=106.784767, 纬度=29.715576
# 47. WGS84坐标: 经度=106.784782, 纬度=29.715576
# 48. WGS84坐标: 经度=106.784782, 纬度=29.715572
# 49. WGS84坐标: 经度=106.784798, 纬度=29.715576
# 50. WGS84坐标: 经度=106.784798, 纬度=29.715576
# 51. WGS84坐标: 经度=106.784813, 纬度=29.715584
# 52. WGS84坐标: 经度=106.784828, 纬度=29.715601
# 53. WGS84坐标: 经度=106.784843, 纬度=29.715609
# 54. WGS84坐标: 经度=106.784866, 纬度=29.715616
# 55. WGS84坐标: 经度=106.784882, 纬度=29.715626
# 56. WGS84坐标: 经度=106.784897, 纬度=29.715633
# 57. WGS84坐标: 经度=106.784912, 纬度=29.715641
# 58. WGS84坐标: 经度=106.784927, 纬度=29.715654
# 59. WGS84坐标: 经度=106.784943, 纬度=29.715670
# 60. WGS84坐标: 经度=106.784958, 纬度=29.715677
# 61. WGS84坐标: 经度=106.784981, 纬度=29.715677
# 62. WGS84坐标: 经度=106.784996, 纬度=29.715687
# 63. WGS84坐标: 经度=106.784996, 纬度=29.715687
# 64. WGS84坐标: 经度=106.785011, 纬度=29.715687
# 65. WGS84坐标: 经度=106.785011, 纬度=29.715687
# 66. WGS84坐标: 经度=106.785027, 纬度=29.715681
# 67. WGS84坐标: 经度=106.785027, 纬度=29.715677
# 68. WGS84坐标: 经度=106.785042, 纬度=29.715670
# 69. WGS84坐标: 经度=106.785042, 纬度=29.715666
# 70. WGS84坐标: 经度=106.785057, 纬度=29.715662
# 71. WGS84坐标: 经度=106.785057, 纬度=29.715662
# 72. WGS84坐标: 经度=106.785072, 纬度=29.715654
# 73. WGS84坐标: 经度=106.785088, 纬度=29.715645
# 74. WGS84坐标: 经度=106.785126, 纬度=29.715633
# 75. WGS84坐标: 经度=106.785126, 纬度=29.715620
# 76. WGS84坐标: 经度=106.785141, 纬度=29.715609
# 77. WGS84坐标: 经度=106.785156, 纬度=29.715601
# 78. WGS84坐标: 经度=106.785156, 纬度=29.715593
# 79. WGS84坐标: 经度=106.785172, 纬度=29.715588
# 80. WGS84坐标: 经度=106.785187, 纬度=29.715580
# 81. WGS84坐标: 经度=106.785202, 纬度=29.715576
# 82. WGS84坐标: 经度=106.785202, 纬度=29.715572
# 83. WGS84坐标: 经度=106.785225, 纬度=29.715572
# 84. WGS84坐标: 经度=106.785240, 纬度=29.715572
# 85. WGS84坐标: 经度=106.785255, 纬度=29.715572
# 86. WGS84坐标: 经度=106.785255, 纬度=29.715572
# 87. WGS84坐标: 经度=106.785271, 纬度=29.715576
# 88. WGS84坐标: 经度=106.785286, 纬度=29.715580
# 89. WGS84坐标: 经度=106.785286, 纬度=29.715584
# 90. WGS84坐标: 经度=106.785301, 纬度=29.715584
# 91. WGS84坐标: 经度=106.785316, 纬度=29.715588
# 92. WGS84坐标: 经度=106.785316, 纬度=29.715593
# 93. WGS84坐标: 经度=106.785332, 纬度=29.715597
# 94. WGS84坐标: 经度=106.785355, 纬度=29.715597
# 95. WGS84坐标: 经度=106.785370, 纬度=29.715597
# 96. WGS84坐标: 经度=106.785370, 纬度=29.715593
# 97. WGS84坐标: 经度=106.785385, 纬度=29.715593
# 98. WGS84坐标: 经度=106.785400, 纬度=29.715593
# 99. WGS84坐标: 经度=106.785416, 纬度=29.715593
# 100. WGS84坐标: 经度=106.785416, 纬度=29.715588
# 101. WGS84坐标: 经度=106.785416, 纬度=29.715584
# 102. WGS84坐标: 经度=106.785431, 纬度=29.715584
# 103. WGS84坐标: 经度=106.785431, 纬度=29.715584
# 104. WGS84坐标: 经度=106.785431, 纬度=29.715580
# 105. WGS84坐标: 经度=106.785446, 纬度=29.715572
# 106. WGS84坐标: 经度=106.785469, 纬度=29.715569
# 107. WGS84坐标: 经度=106.785484, 纬度=29.715559
# 108. WGS84坐标: 经度=106.785484, 纬度=29.715555
# 109. WGS84坐标: 经度=106.785500, 纬度=29.715555
# 110. WGS84坐标: 经度=106.785515, 纬度=29.715551
# ===== 共 110 个坐标点 =====
#
# ===== 接收到的WGS84坐标数据摘要 =====
# --- 坐标 1 ---
#   WGS84坐标: 经度=106.784225, 纬度=29.715706
# --- 坐标 2 ---
#   WGS84坐标: 经度=106.784225, 纬度=29.715702
# --- 坐标 3 ---
#   WGS84坐标: 经度=106.784248, 纬度=29.715702
# --- 坐标 4 ---
#   WGS84坐标: 经度=106.784248, 纬度=29.715702
# --- 坐标 5 ---
#   WGS84坐标: 经度=106.784264, 纬度=29.715702
# --- 坐标 6 ---
#   WGS84坐标: 经度=106.784264, 纬度=29.715702
# --- 坐标 7 ---
#   WGS84坐标: 经度=106.784279, 纬度=29.715702
# --- 坐标 8 ---
#   WGS84坐标: 经度=106.784294, 纬度=29.715702
# --- 坐标 9 ---
#   WGS84坐标: 经度=106.784309, 纬度=29.715706
# --- 坐标 10 ---
#   WGS84坐标: 经度=106.784325, 纬度=29.715706
# --- 坐标 11 ---
#   WGS84坐标: 经度=106.784340, 纬度=29.715702
# --- 坐标 12 ---
#   WGS84坐标: 经度=106.784355, 纬度=29.715698
# --- 坐标 13 ---
#   WGS84坐标: 经度=106.784378, 纬度=29.715702
# --- 坐标 14 ---
#   WGS84坐标: 经度=106.784393, 纬度=29.715702
# --- 坐标 15 ---
#   WGS84坐标: 经度=106.784409, 纬度=29.715702
# --- 坐标 16 ---
#   WGS84坐标: 经度=106.784424, 纬度=29.715702
# --- 坐标 17 ---
#   WGS84坐标: 经度=106.784439, 纬度=29.715702
# --- 坐标 18 ---
#   WGS84坐标: 经度=106.784454, 纬度=29.715698
# --- 坐标 19 ---
#   WGS84坐标: 经度=106.784454, 纬度=29.715702
# --- 坐标 20 ---
#   WGS84坐标: 经度=106.784470, 纬度=29.715702
# --- 坐标 21 ---
#   WGS84坐标: 经度=106.784492, 纬度=29.715698
# --- 坐标 22 ---
#   WGS84坐标: 经度=106.784508, 纬度=29.715702
# --- 坐标 23 ---
#   WGS84坐标: 经度=106.784523, 纬度=29.715706
# --- 坐标 24 ---
#   WGS84坐标: 经度=106.784538, 纬度=29.715710
# --- 坐标 25 ---
#   WGS84坐标: 经度=106.784554, 纬度=29.715702
# --- 坐标 26 ---
#   WGS84坐标: 经度=106.784569, 纬度=29.715694
# --- 坐标 27 ---
#   WGS84坐标: 经度=106.784569, 纬度=29.715681
# --- 坐标 28 ---
#   WGS84坐标: 经度=106.784584, 纬度=29.715681
# --- 坐标 29 ---
#   WGS84坐标: 经度=106.784599, 纬度=29.715677
# --- 坐标 30 ---
#   WGS84坐标: 经度=106.784622, 纬度=29.715670
# --- 坐标 31 ---
#   WGS84坐标: 经度=106.784637, 纬度=29.715662
# --- 坐标 32 ---
#   WGS84坐标: 经度=106.784653, 纬度=29.715658
# --- 坐标 33 ---
#   WGS84坐标: 经度=106.784668, 纬度=29.715654
# --- 坐标 34 ---
#   WGS84坐标: 经度=106.784683, 纬度=29.715645
# --- 坐标 35 ---
#   WGS84坐标: 经度=106.784683, 纬度=29.715588
# --- 坐标 36 ---
#   WGS84坐标: 经度=106.784683, 纬度=29.715576
# --- 坐标 37 ---
#   WGS84坐标: 经度=106.784683, 纬度=29.715584
# --- 坐标 38 ---
#   WGS84坐标: 经度=106.784698, 纬度=29.715580
# --- 坐标 39 ---
#   WGS84坐标: 经度=106.784698, 纬度=29.715576
# --- 坐标 40 ---
#   WGS84坐标: 经度=106.784698, 纬度=29.715576
# --- 坐标 41 ---
#   WGS84坐标: 经度=106.784714, 纬度=29.715576
# --- 坐标 42 ---
#   WGS84坐标: 经度=106.784737, 纬度=29.715576
# --- 坐标 43 ---
#   WGS84坐标: 经度=106.784737, 纬度=29.715576
# --- 坐标 44 ---
#   WGS84坐标: 经度=106.784752, 纬度=29.715576
# --- 坐标 45 ---
#   WGS84坐标: 经度=106.784767, 纬度=29.715576
# --- 坐标 46 ---
#   WGS84坐标: 经度=106.784767, 纬度=29.715576
# --- 坐标 47 ---
#   WGS84坐标: 经度=106.784782, 纬度=29.715576
# --- 坐标 48 ---
#   WGS84坐标: 经度=106.784782, 纬度=29.715572
# --- 坐标 49 ---
#   WGS84坐标: 经度=106.784798, 纬度=29.715576
# --- 坐标 50 ---
#   WGS84坐标: 经度=106.784798, 纬度=29.715576
# --- 坐标 51 ---
#   WGS84坐标: 经度=106.784813, 纬度=29.715584
# --- 坐标 52 ---
#   WGS84坐标: 经度=106.784828, 纬度=29.715601
# --- 坐标 53 ---
#   WGS84坐标: 经度=106.784843, 纬度=29.715609
# --- 坐标 54 ---
#   WGS84坐标: 经度=106.784866, 纬度=29.715616
# --- 坐标 55 ---
#   WGS84坐标: 经度=106.784882, 纬度=29.715626
# --- 坐标 56 ---
#   WGS84坐标: 经度=106.784897, 纬度=29.715633
# --- 坐标 57 ---
#   WGS84坐标: 经度=106.784912, 纬度=29.715641
# --- 坐标 58 ---
#   WGS84坐标: 经度=106.784927, 纬度=29.715654
# --- 坐标 59 ---
#   WGS84坐标: 经度=106.784943, 纬度=29.715670
# --- 坐标 60 ---
#   WGS84坐标: 经度=106.784958, 纬度=29.715677
# --- 坐标 61 ---
#   WGS84坐标: 经度=106.784981, 纬度=29.715677
# --- 坐标 62 ---
#   WGS84坐标: 经度=106.784996, 纬度=29.715687
# --- 坐标 63 ---
#   WGS84坐标: 经度=106.784996, 纬度=29.715687
# --- 坐标 64 ---
#   WGS84坐标: 经度=106.785011, 纬度=29.715687
# --- 坐标 65 ---
#   WGS84坐标: 经度=106.785011, 纬度=29.715687
# --- 坐标 66 ---
#   WGS84坐标: 经度=106.785027, 纬度=29.715681
# --- 坐标 67 ---
#   WGS84坐标: 经度=106.785027, 纬度=29.715677
# --- 坐标 68 ---
#   WGS84坐标: 经度=106.785042, 纬度=29.715670
# --- 坐标 69 ---
#   WGS84坐标: 经度=106.785042, 纬度=29.715666
# --- 坐标 70 ---
#   WGS84坐标: 经度=106.785057, 纬度=29.715662
# --- 坐标 71 ---
#   WGS84坐标: 经度=106.785057, 纬度=29.715662
# --- 坐标 72 ---
#   WGS84坐标: 经度=106.785072, 纬度=29.715654
# --- 坐标 73 ---
#   WGS84坐标: 经度=106.785088, 纬度=29.715645
# --- 坐标 74 ---
#   WGS84坐标: 经度=106.785126, 纬度=29.715633
# --- 坐标 75 ---
#   WGS84坐标: 经度=106.785126, 纬度=29.715620
# --- 坐标 76 ---
#   WGS84坐标: 经度=106.785141, 纬度=29.715609
# --- 坐标 77 ---
#   WGS84坐标: 经度=106.785156, 纬度=29.715601
# --- 坐标 78 ---
#   WGS84坐标: 经度=106.785156, 纬度=29.715593
# --- 坐标 79 ---
#   WGS84坐标: 经度=106.785172, 纬度=29.715588
# --- 坐标 80 ---
#   WGS84坐标: 经度=106.785187, 纬度=29.715580
# --- 坐标 81 ---
#   WGS84坐标: 经度=106.785202, 纬度=29.715576
# --- 坐标 82 ---
#   WGS84坐标: 经度=106.785202, 纬度=29.715572
# --- 坐标 83 ---
#   WGS84坐标: 经度=106.785225, 纬度=29.715572
# --- 坐标 84 ---
#   WGS84坐标: 经度=106.785240, 纬度=29.715572
# --- 坐标 85 ---
#   WGS84坐标: 经度=106.785255, 纬度=29.715572
# --- 坐标 86 ---
#   WGS84坐标: 经度=106.785255, 纬度=29.715572
# --- 坐标 87 ---
#   WGS84坐标: 经度=106.785271, 纬度=29.715576
# --- 坐标 88 ---
#   WGS84坐标: 经度=106.785286, 纬度=29.715580
# --- 坐标 89 ---
#   WGS84坐标: 经度=106.785286, 纬度=29.715584
# --- 坐标 90 ---
#   WGS84坐标: 经度=106.785301, 纬度=29.715584
# --- 坐标 91 ---
#   WGS84坐标: 经度=106.785316, 纬度=29.715588
# --- 坐标 92 ---
#   WGS84坐标: 经度=106.785316, 纬度=29.715593
# --- 坐标 93 ---
#   WGS84坐标: 经度=106.785332, 纬度=29.715597
# --- 坐标 94 ---
#   WGS84坐标: 经度=106.785355, 纬度=29.715597
# --- 坐标 95 ---
#   WGS84坐标: 经度=106.785370, 纬度=29.715597
# --- 坐标 96 ---
#   WGS84坐标: 经度=106.785370, 纬度=29.715593
# --- 坐标 97 ---
#   WGS84坐标: 经度=106.785385, 纬度=29.715593
# --- 坐标 98 ---
#   WGS84坐标: 经度=106.785400, 纬度=29.715593
# --- 坐标 99 ---
#   WGS84坐标: 经度=106.785416, 纬度=29.715593
# --- 坐标 100 ---
#   WGS84坐标: 经度=106.785416, 纬度=29.715588
# --- 坐标 101 ---
#   WGS84坐标: 经度=106.785416, 纬度=29.715584
# --- 坐标 102 ---
#   WGS84坐标: 经度=106.785431, 纬度=29.715584
# --- 坐标 103 ---
#   WGS84坐标: 经度=106.785431, 纬度=29.715584
# --- 坐标 104 ---
#   WGS84坐标: 经度=106.785431, 纬度=29.715580
# --- 坐标 105 ---
#   WGS84坐标: 经度=106.785446, 纬度=29.715572
# --- 坐标 106 ---
#   WGS84坐标: 经度=106.785469, 纬度=29.715569
# --- 坐标 107 ---
#   WGS84坐标: 经度=106.785484, 纬度=29.715559
# --- 坐标 108 ---
#   WGS84坐标: 经度=106.785484, 纬度=29.715555
# --- 坐标 109 ---
#   WGS84坐标: 经度=106.785500, 纬度=29.715555
# --- 坐标 110 ---
#   WGS84坐标: 经度=106.785515, 纬度=29.715551
#
# ===== 接收完成，共110个坐标点 =====
# [转换完成] GCJ02坐标: 经度=106.788231, 纬度=29.713017
# [转换完成] GCJ02坐标: 经度=106.788231, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788254, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788254, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788270, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788270, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788285, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788300, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788315, 纬度=29.713017
# [转换完成] GCJ02坐标: 经度=106.788331, 纬度=29.713017
# [转换完成] GCJ02坐标: 经度=106.788346, 纬度=29.713013
# [转换完成] GCJ02坐标: 经度=106.788361, 纬度=29.713009
# [转换完成] GCJ02坐标: 经度=106.788384, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788399, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788415, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788430, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788445, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788460, 纬度=29.713008
# [转换完成] GCJ02坐标: 经度=106.788460, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788476, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788498, 纬度=29.713008
# [转换完成] GCJ02坐标: 经度=106.788514, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788529, 纬度=29.713016
# [转换完成] GCJ02坐标: 经度=106.788544, 纬度=29.713020
# [转换完成] GCJ02坐标: 经度=106.788560, 纬度=29.713012
# [转换完成] GCJ02坐标: 经度=106.788575, 纬度=29.713004
# [转换完成] GCJ02坐标: 经度=106.788575, 纬度=29.712991
# [转换完成] GCJ02坐标: 经度=106.788590, 纬度=29.712991
# [转换完成] GCJ02坐标: 经度=106.788605, 纬度=29.712987
# [转换完成] GCJ02坐标: 经度=106.788628, 纬度=29.712980
# [转换完成] GCJ02坐标: 经度=106.788643, 纬度=29.712972
# [转换完成] GCJ02坐标: 经度=106.788659, 纬度=29.712968
# [转换完成] GCJ02坐标: 经度=106.788674, 纬度=29.712964
# [转换完成] GCJ02坐标: 经度=106.788689, 纬度=29.712955
# [转换完成] GCJ02坐标: 经度=106.788689, 纬度=29.712898
# [转换完成] GCJ02坐标: 经度=106.788689, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788689, 纬度=29.712894
# [转换完成] GCJ02坐标: 经度=106.788704, 纬度=29.712890
# [转换完成] GCJ02坐标: 经度=106.788704, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788704, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788720, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788743, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788743, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788758, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788773, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788773, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788788, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788788, 纬度=29.712882
# [转换完成] GCJ02坐标: 经度=106.788804, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788804, 纬度=29.712886
# [转换完成] GCJ02坐标: 经度=106.788819, 纬度=29.712894
# [转换完成] GCJ02坐标: 经度=106.788834, 纬度=29.712911
# [转换完成] GCJ02坐标: 经度=106.788849, 纬度=29.712919
# [转换完成] GCJ02坐标: 经度=106.788872, 纬度=29.712926
# [转换完成] GCJ02坐标: 经度=106.788888, 纬度=29.712936
# [转换完成] GCJ02坐标: 经度=106.788903, 纬度=29.712943
# [转换完成] GCJ02坐标: 经度=106.788918, 纬度=29.712951
# [转换完成] GCJ02坐标: 经度=106.788933, 纬度=29.712964
# [转换完成] GCJ02坐标: 经度=106.788949, 纬度=29.712980
# [转换完成] GCJ02坐标: 经度=106.788964, 纬度=29.712987
# [转换完成] GCJ02坐标: 经度=106.788987, 纬度=29.712987
# [转换完成] GCJ02坐标: 经度=106.789002, 纬度=29.712997
# [转换完成] GCJ02坐标: 经度=106.789002, 纬度=29.712997
# [转换完成] GCJ02坐标: 经度=106.789017, 纬度=29.712997
# [转换完成] GCJ02坐标: 经度=106.789017, 纬度=29.712997
# [转换完成] GCJ02坐标: 经度=106.789033, 纬度=29.712991
# [转换完成] GCJ02坐标: 经度=106.789033, 纬度=29.712987
# [转换完成] GCJ02坐标: 经度=106.789048, 纬度=29.712980
# [转换完成] GCJ02坐标: 经度=106.789048, 纬度=29.712976
# [转换完成] GCJ02坐标: 经度=106.789063, 纬度=29.712972
# [转换完成] GCJ02坐标: 经度=106.789063, 纬度=29.712972
# [转换完成] GCJ02坐标: 经度=106.789078, 纬度=29.712964
# [转换完成] GCJ02坐标: 经度=106.789094, 纬度=29.712955
# [转换完成] GCJ02坐标: 经度=106.789132, 纬度=29.712943
# [转换完成] GCJ02坐标: 经度=106.789132, 纬度=29.712930
# [转换完成] GCJ02坐标: 经度=106.789147, 纬度=29.712919
# [转换完成] GCJ02坐标: 经度=106.789162, 纬度=29.712911
# [转换完成] GCJ02坐标: 经度=106.789162, 纬度=29.712903
# [转换完成] GCJ02坐标: 经度=106.789178, 纬度=29.712898
# [转换完成] GCJ02坐标: 经度=106.789193, 纬度=29.712889
# [转换完成] GCJ02坐标: 经度=106.789208, 纬度=29.712885
# [转换完成] GCJ02坐标: 经度=106.789208, 纬度=29.712881
# [转换完成] GCJ02坐标: 经度=106.789231, 纬度=29.712881
# [转换完成] GCJ02坐标: 经度=106.789246, 纬度=29.712881
# [转换完成] GCJ02坐标: 经度=106.789261, 纬度=29.712881
# [转换完成] GCJ02坐标: 经度=106.789261, 纬度=29.712881
# [转换完成] GCJ02坐标: 经度=106.789277, 纬度=29.712885
# [转换完成] GCJ02坐标: 经度=106.789292, 纬度=29.712889
# [转换完成] GCJ02坐标: 经度=106.789292, 纬度=29.712893
# [转换完成] GCJ02坐标: 经度=106.789307, 纬度=29.712893
# [转换完成] GCJ02坐标: 经度=106.789322, 纬度=29.712897
# [转换完成] GCJ02坐标: 经度=106.789322, 纬度=29.712902
# [转换完成] GCJ02坐标: 经度=106.789338, 纬度=29.712906
# [转换完成] GCJ02坐标: 经度=106.789361, 纬度=29.712906
# [转换完成] GCJ02坐标: 经度=106.789376, 纬度=29.712906
# [转换完成] GCJ02坐标: 经度=106.789376, 纬度=29.712902
# [转换完成] GCJ02坐标: 经度=106.789391, 纬度=29.712902
# [转换完成] GCJ02坐标: 经度=106.789406, 纬度=29.712902
# [转换完成] GCJ02坐标: 经度=106.789422, 纬度=29.712902
# [转换完成] GCJ02坐标: 经度=106.789422, 纬度=29.712897
# [转换完成] GCJ02坐标: 经度=106.789422, 纬度=29.712893
# [转换完成] GCJ02坐标: 经度=106.789437, 纬度=29.712893
# [转换完成] GCJ02坐标: 经度=106.789437, 纬度=29.712893
# [转换完成] GCJ02坐标: 经度=106.789437, 纬度=29.712889
# [转换完成] GCJ02坐标: 经度=106.789452, 纬度=29.712881
# [转换完成] GCJ02坐标: 经度=106.789475, 纬度=29.712878
# [转换完成] GCJ02坐标: 经度=106.789490, 纬度=29.712868
# [转换完成] GCJ02坐标: 经度=106.789490, 纬度=29.712864
# [转换完成] GCJ02坐标: 经度=106.789506, 纬度=29.712864
# [转换完成] GCJ02坐标: 经度=106.789521, 纬度=29.712860
# 已生成实时轨迹地图: realtime_map.html
# 轨迹包含 110 个GCJ02坐标点
# 起点GCJ02坐标: 经度 106.788231, 纬度 29.713017
# 终点GCJ02坐标: 经度 106.789521, 纬度 29.712860
